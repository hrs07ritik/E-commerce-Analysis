# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
sales = pd.read_csv("ecommerce.csv")

# %%
sales
# Out:
#       Order Date Product Name     Category Region  Quantity  Sales   Profit
# 0     2024-12-31      Printer       Office  North         4   3640   348.93
# 1     2022-11-27        Mouse  Accessories   East         7   1197   106.53
# 2     2022-05-11       Tablet  Electronics  South         5   5865   502.73
# 3     2024-03-16        Mouse  Accessories  South         2    786   202.87
# 4     2022-09-10        Mouse  Accessories   West         1    509   103.28
# ...          ...          ...          ...    ...       ...    ...      ...
# 3495  2023-02-15      Monitor  Accessories  North         4   4064   771.16
# 3496  2022-09-18      Monitor  Accessories   East         1   1117   119.89
# 3497  2022-04-12       Laptop  Electronics  South         4    260    66.02
# 3498  2022-01-18      Printer       Office  South         3    222    50.28
# 3499  2024-11-01   Smartwatch  Electronics   East         9  10530  1777.32
#
# [3500 rows x 7 columns]

# %%
sales.head()
# Out:
#    Order Date Product Name     Category Region  Quantity  Sales  Profit
# 0  2024-12-31      Printer       Office  North         4   3640  348.93
# 1  2022-11-27        Mouse  Accessories   East         7   1197  106.53
# 2  2022-05-11       Tablet  Electronics  South         5   5865  502.73
# 3  2024-03-16        Mouse  Accessories  South         2    786  202.87
# 4  2022-09-10        Mouse  Accessories   West         1    509  103.28

# %%
sales.tail()
# Out:
#       Order Date Product Name     Category Region  Quantity  Sales   Profit
# 3495  2023-02-15      Monitor  Accessories  North         4   4064   771.16
# 3496  2022-09-18      Monitor  Accessories   East         1   1117   119.89
# 3497  2022-04-12       Laptop  Electronics  South         4    260    66.02
# 3498  2022-01-18      Printer       Office  South         3    222    50.28
# 3499  2024-11-01   Smartwatch  Electronics   East         9  10530  1777.32

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order Date    3500 non-null   object
#  1   Product Name  3500 non-null   object
#  2   Category      3500 non-null   object
#  3   Region        3500 non-null   object
#  4   Quantity      3500 non-null   int64
#  5   Sales         3500 non-null   int64
#  6   Profit        3500 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 191.5+ KB

# %%
sales.describe().T
# Out:
#            count         mean          std    min       25%      50%  \
# Quantity  3500.0     4.931714     2.575895   1.00     3.000     5.00
# Sales     3500.0  3047.966000  2440.213237  51.00  1049.500  2350.50
# Profit    3500.0   527.047203   504.139732   6.97   158.695   361.07
#
#                75%       max
# Quantity     7.000      9.00
# Sales     4537.000  10782.00
# Profit     729.125   2946.93

# %%
sales.columns
# Out:
# Index(['Order Date', 'Product Name', 'Category', 'Region', 'Quantity', 'Sales',
#        'Profit'],
#       dtype='object')

# %%
sales.shape
# Out:
# (3500, 7)

# %%
sales.isnull().sum()
# Out:
# Order Date      0
# Product Name    0
# Category        0
# Region          0
# Quantity        0
# Sales           0
# Profit          0
# dtype: int64

# %%
sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
sales["Product Name"].unique()
# Out:
# array(['Printer', 'Mouse', 'Tablet', 'Camera', 'Headphones', 'Smartwatch',
#        'Monitor', 'Smartphone', 'Keyboard', 'Laptop'], dtype=object)

# %%
sales["Category"].unique()
# Out:
# array(['Office', 'Accessories', 'Electronics'], dtype=object)

# %%
sales["Region"].unique()
# Out:
# array(['North', 'East', 'South', 'West'], dtype=object)

# %%
sns.countplot(x = "Category", data = sales)
plt.title("Top Category")
plt.xlabel("Category")
plt.ylabel("Count")
plt.grid(True)
plt.tight_layout()

# %%
sns.countplot(x = "Region", data = sales)
plt.title("Top Region")
plt.xlabel("Region")
plt.ylabel("Count")
plt.grid(True)
plt.tight_layout()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x = "Product Name", data = sales)
plt.title("Top Product")
plt.xlabel("Product Name")
plt.ylabel("Count")
plt.grid(True)
plt.tight_layout()

# %%
sns.scatterplot(x ="Sales" ,y = "Profit", data = sales)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
sns.boxplot(x = "Category", y = "Sales", data = sales)
# Out:
# <Axes: xlabel='Category', ylabel='Sales'>

# %%
sns.boxplot(x = "Region", y = "Sales", data = sales)
# Out:
# <Axes: xlabel='Region', ylabel='Sales'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x = "Product Name", y = "Sales", data = sales)
# Out:
# <Axes: xlabel='Product Name', ylabel='Sales'>

# %%
sns.boxplot(x = "Category", y = "Profit", data = sales)
# Out:
# <Axes: xlabel='Category', ylabel='Profit'>

# %%
sns.boxplot(x = "Region", y = "Profit", data = sales)
# Out:
# <Axes: xlabel='Region', ylabel='Profit'>

# %%
sns.boxplot(x = "Product Name", y = "Profit", data = sales)
plt.xticks(rotation = 90)
plt.show()

# %%
sales["Order Date"] = pd.to_datetime(sales["Order Date"])
sales["Year"] = sales["Order Date"].dt.year
sales["Month"] = sales["Order Date"].dt.month

# %%
sales.head()
# Out:
#   Order Date Product Name     Category Region  Quantity  Sales  Profit  Year  \
# 0 2024-12-31      Printer       Office  North         4   3640  348.93  2024
# 1 2022-11-27        Mouse  Accessories   East         7   1197  106.53  2022
# 2 2022-05-11       Tablet  Electronics  South         5   5865  502.73  2022
# 3 2024-03-16        Mouse  Accessories  South         2    786  202.87  2024
# 4 2022-09-10        Mouse  Accessories   West         1    509  103.28  2022
#
#    Month
# 0     12
# 1     11
# 2      5
# 3      3
# 4      9

# %%
plt.figure(figsize = (10,6))
sales.groupby("Year")["Sales"].sum().plot(kind="line", marker="o")
plt.grid(True)

# %%
sales.groupby("Month")["Sales"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Month'>

# %%
sales.groupby("Category")["Sales"].sum().sort_values(ascending=False)
# Out:
# Category
# Electronics    5326074
# Accessories    4247591
# Office         1094216
# Name: Sales, dtype: int64

# %%
sales.groupby("Category")["Profit"].sum().sort_values(ascending=False)
# Out:
# Category
# Electronics    923185.59
# Accessories    736084.74
# Office         185394.88
# Name: Profit, dtype: float64

# %%
sales.groupby("Region")["Sales"].sum()
# Out:
# Region
# East     2675110
# North    2488773
# South    2659548
# West     2844450
# Name: Sales, dtype: int64

# %%
sales.groupby("Region")["Profit"].sum()
# Out:
# Region
# East     464888.46
# North    426314.75
# South    458103.27
# West     495358.73
# Name: Profit, dtype: float64

# %%
sales.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Camera        1177381
# Monitor       1160048
# Printer       1094216
# Mouse         1074398
# Smartphone    1069681
# Smartwatch    1049211
# Keyboard      1024507
# Tablet        1023928
# Laptop        1005873
# Headphones     988638
# Name: Sales, dtype: int64

# %%
sales.groupby("Product Name")["Profit"].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Camera        207630.99
# Monitor       202028.17
# Mouse         185763.69
# Laptop        185756.81
# Printer       185394.88
# Smartphone    183296.97
# Smartwatch    178995.81
# Keyboard      175814.68
# Headphones    172478.20
# Tablet        167505.01
# Name: Profit, dtype: float64

# %%
sales[["Quantity","Sales","Profit"]].corr()
# Out:
#           Quantity     Sales    Profit
# Quantity  1.000000  0.662468  0.560651
# Sales     0.662468  1.000000  0.832826
# Profit    0.560651  0.832826  1.000000

# %%
total_sales = sales["Sales"].sum()
total_profit = sales["Profit"].sum()
total_orders = sales.shape[0]
total_quantity = sales["Quantity"].sum()

# %%
total_quantity
# Out:
# np.int64(17261)

# %%
total_orders
# Out:
# 3500

# %%
total_profit
# Out:
# np.float64(1844665.21)

# %%
total_sales
# Out:
# np.int64(10667881)

# %%
sales["Profit Margin"] = sales["Profit"] / sales["Sales"]

# %%
sales.head()
# Out:
#   Order Date Product Name     Category Region  Quantity  Sales  Profit  Year  \
# 0 2024-12-31      Printer       Office  North         4   3640  348.93  2024
# 1 2022-11-27        Mouse  Accessories   East         7   1197  106.53  2022
# 2 2022-05-11       Tablet  Electronics  South         5   5865  502.73  2022
# 3 2024-03-16        Mouse  Accessories  South         2    786  202.87  2024
# 4 2022-09-10        Mouse  Accessories   West         1    509  103.28  2022
#
#    Month  Profit Margin
# 0     12       0.095860
# 1     11       0.088997
# 2      5       0.085717
# 3      3       0.258104
# 4      9       0.202908
